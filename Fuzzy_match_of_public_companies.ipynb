# %% [markdown]
# ### Fuzzy_match_of_public
# - Wang Jin & Zhongjie He
#
# #### Problem describtion
# The aim of this project is to pick the public companies(have listed on American stock exchanges) from the original 222,450 companies(some are repeated). The file **work1.csv** is the work file and the **work2** is the public companies(more than 6,000) in United States' share exchanges. Mainly we apply *fuzzy wuzzy* algorithm and picked the required ones. https://github.com/seatgeek/fuzzywuzzy (developped by SeatGeet)
#
# **There are two main difficulties. **
# - The first names in the file with unchecked companies are not very formal, say **'Apple company '** instead of **'Apple Inc'**. We designed the *fuzzy wuzzy* value by making experiments manually in advance.
# - The second is massive data leads to much running time (it is estimated more than **12 hours** for the first version programe). We reduced it to **less than five minutes** by devide the matching procedure into two steps after carefully observed the data structure.

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import warnings
warnings.filterwarnings('ignore')
# fuzz.token_set_ratio("Advanced Semiconductor Engineering, Inc.", "Advance Pain Centers"    )
# Out:
# D:\Users\jinwa\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#1.import company data we want search
co = pd.read_csv("work1.csv", sep=',')
# co.head()
co.describe()
# Out:
#                         coname   money    year   comma    haha
# count                   222450  222450  222450  222447  222447
# unique                   41497   12710      39       1     537
# top     Blue Cross/Blue Shield     ,0,    2009       ,   Y4000
# freq                       449   49595    9547  222447   27719

# %%
#import public companies data
share = pd.read_csv("work2.csv")
share.sort_values('sharename', inplace=True)
share.reset_index(inplace=True)
share.drop('index', axis=1, inplace=True)
share
# Out:
#                                               sharename       sharecode
# 0                               1-800 FLOWERS.COM, Inc.            FLWS
# 1                1347 Property Insurance Holdings, Inc.             PIH
# 2                              180 Degree Capital Corp.            TURN
# 3                         1st Constitution Bancorp (NJ)            FCCY
# 4                                1st Source Corporation            SRCE
# 5                                  21Vianet Group, Inc.            VNET
# 6                               22nd Century Group, Inc            XXII
# 7                                              2U, Inc.            TWOU
# 8                                3D Systems Corporation             DDD
# 9                                            3M Company             MMM
# 10                                      500.com Limited            WBAI
# 11                                          51job, Inc.            JOBS
# 12                                          58.com Inc.            WUBA
# 13                           8point3 Energy Partners LP            CAFD
# 14                                              8x8 Inc            EGHT
# 15                                      A V Homes, Inc.            AVHI
# 16                         A-Mark Precious Metals, Inc.            AMRK
# 17                                    A. Schulman, Inc.            SHLM
# 18                                A.H. Belo Corporation             AHC
# 19                                   A10 Networks, Inc.            ATEN
# 20                                   AAC Holdings, Inc.             AAC
# 21                                           AAON, Inc.            AAON
# 22                                            AAR Corp.             AIR
# 23                                         ABAXIS, Inc.            ABAX
# 24                                              ABB Ltd             ABB
# 25                                        ABIOMED, Inc.            ABMD
# 26                          ABM Industries Incorporated             ABM
# 27                                         AC Immune SA            ACIU
# 28                          ACADIA Pharmaceuticals Inc.            ACAD
# 29                                  ACI Worldwide, Inc.            ACIW
# ...                                                 ...             ...
# 6727         iShares S&P Global Clean Energy Index Fund            ICLN
# 6728    iShares S&P Global Timber & Forestry Index Fund            WOOD
# 6729              iShares S&P India Nifty 50 Index Fund            INDY
# 6730               iShares S&P Small-Cap 600 Growth ETF             IJT
# 6731                        iShares Select Dividend ETF             DVY
# 6732                    iShares Short Treasury Bond ETF             SHV
# 6733                       iShares U.S. Credit Bond ETF            CRED
# 6734                   iShares U.S. Preferred Stock ETF             PFF
# 6735  iShares iBoxx $ High Yield ex Oil & Gas Corpor...            HYXE
# 6736                               iStar Financial Inc.          STAR^I
# 6737                               iStar Financial Inc.          STAR^G
# 6738                               iStar Financial Inc.          STAR^F
# 6739                               iStar Financial Inc.          STAR^E
# 6740                               iStar Financial Inc.          STAR^D
# 6741                               iStar Financial Inc.  STAR
# 6742                                          icad inc.            ICAD
# 6743                                 inTest Corporation            INTT
# 6744                                    j2 Global, Inc.            JCOM
# 6745                           lululemon athletica inc.            LULU
# 6746                             magicJack VocalTec Ltd            CALL
# 6747                                      pSivida Corp.            PSDV
# 6748                                  pdvWireless, Inc.            PDVW
# 6749                               rEVO Biologics, Inc.            RBIO
# 6750                             root9B Holdings, Inc.             RTNB
# 6751                                  support.com, Inc.            SPRT
# 6752                                       trivago N.V.            TRVG
# 6753                                        tronc, Inc.            TRNC
# 6754                                       uniQure N.V.            QURE
# 6755                              vTv Therapeutics Inc.            VTVT
# 6756                                        voxeljet AG            VJET
#
# [6757 rows x 2 columns]

# %%
#2.make company name unique
co_name = co[['coname']]
co_name.drop_duplicates(inplace=True)
co_name.sort_values('coname', inplace=True)
co_name.reset_index(inplace=True)
co_name.drop(['index'], axis=1, inplace=True)
co_name.head()
# Out:
#               coname
# 0     1-800 Contacts
# 1    1-800-DoNotCall
# 2      1-800-Doctors
# 3  1-800-Flowers.com
# 4      1-800-Medivan

# %%
co_name.describe()
# Out:
#                                     coname
# count                                41497
# unique                               41497
# top     National Milk Producers Federation
# freq                                     1

# %%
#3. use fuzzy match algorithm 
import time
t0 = time.time()

pre=0
name2sharecode = {}

offset = 0
limit = len(co_name)

for j, co_row in co_name.iloc[offset: offset + limit].iterrows():
    cur = round((j - offset) / limit * 100)
    if cur > pre:
        pre = cur
        print(f'{cur}%...')   #give progress bar
    
    share_pre2 = share[share['sharename'].str.upper().str.startswith(co_row['coname'][0:2])]
    
    #match company names
    for i, share_row in share_pre2.iterrows():
        if fuzz.token_set_ratio(share_row['sharename'], co_row['coname']) > 75:
            name2sharecode[co_row['coname']] = share_row['sharecode']
            print(i, j)
            break
print(time.time() - t0)
import json
json.dump(name2sharecode, open('name2sharecode{}.json'.format(offset), 'w'))
name2sharecode
# Out:
# 0 3
# 7 60
# 8 78
# 14 129
# 19 153
# 22 161
# 22 164
# 25 177
# 26 178
# 87 182
# 117 190
# 1.0%...
# 31 220
# 149 221
# 145 223
# 31 225
# 33 226
# 149 230
# 139 232
# 35 237
# 35 238
# 158 239
# 44 300
# 240 312
# 262 319
# 49 324
# 49 326
# 354 328
# 313 329
# 53 335
# 48 338
# 53 341
# 58 354
# 418 361
# 418 362
# 442 371
# 61 389
# 476 391
# 65 396
# 65 397
# 66 401
# 521 406
# 69 425
# 69 427
# 70 429
# 621 463
#  'ACA International': 'ATV',
#  'ADA Technologies': 'AEY',
#  'ADA-ES Inc': 'ADXSW',
#  'ADCOR Industries': 'AEIS',
#  'ADI Technologies': 'AEY',
#  'ADOMANI Inc': 'ADOM',
#  'ADS Inc': 'ADXSW',
#  'ADSI Inc': 'ASIX',
#  'AECOM Global': 'ACM',
#  'AECOM Technology Corp': 'ACM',
#  'AEGON NV': 'AEB',
#  'AK Steel': 'AKS',
#  'ALLETE Inc': 'ALE',
#  'ALT Solutions': 'MDRX',
#  'AM Networks Inc': 'AMCX',
#  'AMC Networks': 'AMCX',
#  'AMD Industries': 'ARII',
#  'AMEC': 'AMFW',
#  'AMG Healthcare Services': 'AMN',
#  'AMI Entertainment': 'AMC',
#  'AMN Healthcare Services': 'AMN',
#  'ANSAR Inc': 'ANSS',
#  'AON PLC': 'AON',
#  'AON plc': 'AON',
#  'API Technologies': 'AGTC',
#  'ARCA Biopharma': 'ABIO',
#  'ARCCA Inc': 'ARCH',
#  'ARGUS INTERNATIONAL': 'ARRS',
#  'ARMA International': 'ARRS',
#  'ASA': 'ASA',
#  'ASCENT': 'ASCMA',
#  'AT&T': 'T',
#  'AT&T Inc': 'T',
#  'ATA': 'ATAI',
#  'AWARE': 'AWRE',
#  'BAE Systems': 'BLDP',
#  'BAST Services': 'BBSI',
#  'BCO Inc': 'BCE',
#  'BCS Inc': 'BCE',
#  'BEST Inc': 'BSTI',
#  'BHP Billiton': 'BHP',
#  'BIFMA International': 'BKYI',
#  'BP': 'BPT',
#  'BW Technologies': 'BWXT',
#  'BWX Technologies': 'BWXT',
#  'CA': 'CA',
#  'CA Inc': 'CA',
#  'CACI International': 'CACI',
#  'CAE Inc': 'CA',
#  'CAMP Inc': 'CA',
#  'CAN Capital': 'CBF',
#  'CARE': 'CRCM',
#  'CBE Group': 'CBG',
#  'CBRE Group': 'CBG',
#  'CEMEX Inc': 'CETX',
#  'CES Environmental': 'CECE',
#  'CF Industries': 'CF',
#  'CG Corr Group': 'GIB',
#  'CGI Group': 'GIB',
#  'CHF International': 'CRL',
#  'CHS Inc': 'CHSCL',
#  'CIT Group': 'CIT',
#  'CME Group': 'CME',
#  'CME Group Inc': 'CME',
#  'CMS Energy': 'CMS',
#  'CNG Financial': 'CNA',
#  'CNH Industrial': 'CNHI',
#  'CNL Financial': 'CNA',
#  'CNO Financial': 'CNA',
#  'CNO Financial Group': 'CNO',
#  'COCO Communications': 'CCOI',
#  'COLSA Corp': 'CRVL',
#  'CONSOL Energy': 'CNX',
#  'CPI Inc': 'CPF',
#  'CPMG Inc': 'CPF',
#  'CRH PLC': 'CRH',
#  'CRH plc': 'CRH',
#  'CRISPR Therapeutics': 'CRSP',
#  'CRT Inc': 'CRAY',
#  'CSCM Inc': 'CSPI',
#  'CVR Energy': 'CVI',
#  'CVS Health': 'CVS',
#  'DC Trust': 'DCT',
#  'DDR Corp': 'DDR',
#  'DIBC Holdings': 'SAUC',
#  'DISH Network': 'DISH',
#  'DSE Inc': 'DSW',
#  'DSS Inc': 'DSW',
#  'DTE Energy': 'DTQ',
#  'E*TRADE Financial': 'ETFC',
#  'EBI Inc': 'EBIX',
#  'EMCOR Group': 'EME',
#  'ENS Resources': 'ENRJ',
#  'EOG Resources': 'EOG',
#  'ERA': 'ERA',
#  'ESCO Electronics': 'ESP',
#  'F5 Networks': 'FFIV',
#  'FALA Technologies Inc': 'FARO',
#  'FIA Foundation': 'FFWM',
#  'FINCA International': 'IFV',
#  'FIRST': 'FRC^D',
#  'FLIR Systems': 'FLIR',
#  'GAIN Capital Group': 'GCAP',
#  'GEO Group': 'GEO',
#  'GSE Systems': 'GVP',
#  'GTS Inc': 'GTXI',
#  'H&R Block': 'HRB',
#  'HCA Healthcare': 'HCA',
#  'HCA Inc': 'HCA',
#  'HFF Inc': 'HF',
#  'HFX Inc': 'HF',
#  'HMS Holdings': 'HMSY',
#  'HP Inc': 'HPQ',
#  'HSBC Holdings': 'HSEB',
#  'HST Inc': 'HSNI',
#  'HTG Molecular Diagnostics': 'HTGM',
#  'IAC/InterActiveCorp': 'IAC',
#  'IBP Inc': 'IBIO',
#  'IBS Inc': 'IBIO',
#  'ICF International': 'ICFI',
#  'ICF Kaiser International': 'ICFI',
#  'ICIX International': 'ICFI',
#  'ICON International': 'ICFI',
#  'ICOR International': 'ICFI',
#  'ICTS International': 'ICFI',
#  'ICU Medical Inc': 'ICUI',
#  'IDACORP Inc': 'IDA',
#  'IDEXX Laboratories': 'IDXX',
#  'IMET Laboratories': 'IPXL',
#  'ING Group': 'ISP.CL',
#  'INSYS Therapeutics': 'NVIV',
#  'INTL FCStone Inc': 'INTL',
#  'ION Geophysical Corp': 'IO',
#  'IPS Inc': 'IPAS',
#  'IPSCO Inc': 'IPAS',
#  'ISP Technologies': 'XT',
#  'ISPA Technologies': 'XT',
#  'ITA Inc': 'ITT',
#  'ITRON Inc': 'ITRI',
#  'J2 Global Communications': 'JCOM',
#  'K12 Inc': 'LRN',
#  'KAR Holdings': 'KDMN',
#  'KB Home': 'KBH',
#  'KBR Inc': 'KBR',
#  'KKR & Co': 'KKR',
#  'KLA-Tencor Corp': 'KLAC',
#  'KMX Chemical': 'KMG',
#  'L Brands': 'LB',
#  'LA Partners': 'LMRKP',
#  'LA Quinta Inns': 'LQ',
#  'LC Industries': 'LCII',
#  'LEARN Coalition': 'LEA',
#  'LEEP Holdings & Balkrete Inc': 'LDOS',
#  'LHC Group': 'LHCG',
#  'LION Inc': 'LPCN',
#  'LSB Industries': 'LYTS',
#  'M Financial Group': 'MBTF',
#  'M&T Bank': 'MTB.WS',
#  'M/I Homes Inc': 'MHO',
#  'MAC Inc': 'MCHX',
#  'MAF Bancorp': 'MGYR',
#  'MBDA Inc': 'MBI',
#  'MBI Inc': 'MBI',
#  'MBIA Inc': 'MBI',
#  'MDU Resources Group': 'MDU',
#  'MEDInstill Inc': 'MED',
#  'MERIT Inc': 'MED',
#  'MG International': 'MGM',
#  'MGIC Investment Corp': 'MTG',
#  'MGM Resorts International': 'MGM',
#  'MGP Ingredients': 'MGPI',
#  'MIC Industries': 'MLR',
#  'MKS Instruments': 'MKSI',
#  'MSE Inc': 'MSCI',
#  'MTS Systems': 'MTSC',
#  'NAC International': 'NAII',
#  'NACCO Industries': 'NC',
#  'NACE International': 'NAII',
#  'NASDAQ Stock Market': 'ATEST.A',
#  'NCL Holdings': 'NCSM',
#  'NCM Holdings': 'NCSM',
#  'NEC Corp': 'NVRO',
#  'NETWORK': 'NTIP',
#  'NIC Holding': 'NODK',
#  'NIC Inc': 'EGOV',
#  'NMI Holdings': 'NMIH',
#  'NQ Mobile': 'NQ',
#  'NRG Energy': 'NRG',
#  'NVIDIA Corp': 'NVDA',
#  'NVR Inc': 'NVR',
#  'NXP Semiconductors': 'NXPI',
#  'NXP Semiconductors USA': 'NXPI',
#  'OFG Bancorp': 'OFG^D',
#  'OGE Energy': 'OGE',
#  'OM Group': 'OMC',
#  'ONEOK Inc': 'OKE',
#  'OPKO Health': 'OPK',
#  'ORBIS International': 'OFIX',
#  'ORIX Corp': 'IX',
#  'OSI Systems': 'OSIS',
#  'PBF Energy': 'PBF',
#  'PCI Communications Inc': 'CNXN',
#  'PEC Inc': 'PEP',
#  'PEF Services': 'PFSI',
#  'PHH Corp': 'PHH',
#  'PHI Inc': 'PHIIK',
#  'PIVX Solutions': 'PPSI',
#  'PNC Financial Services': 'PNC',
#  'PNM Resources': 'PNM',
#  'POMCO': 'PKX',
#  'POPPA Inc': 'BPOPM',
#  'PPG Industries': 'PPG',
#  'PRIMEDIA Inc': 'PRI',
#  'PTC Inc': 'PTC',
#  'PTC Therapeutics': 'PTCT',
#  'PTPN Inc': 'PTC',
#  'PURE Bioscience': 'PLSE',
#  'PVH Corp': 'PVH',
#  'QAI Inc': 'QADB',
#  'QEP Resources': 'QEP',
#  'RAIT Financial Trust': 'RAS',
#  'RE2 Inc': 'REIS',
#  'RED-INC': 'RHT',
#  'REL Inc': 'REIS',
#  'REMAX International': 'RDIB',
#  'REX American Resources Corp': 'REX',
#  'RH Strategies': 'RH',
#  'RPM Inc': 'RES',
#  'RPM International': 'RPM',
#  'S&P Global': 'SPGI',
#  'SAFE': 'SB^B',
#  'SAIC Inc': 'SAIA',
#  'SAP SE': 'SAP',
#  'SAVVIS Communications': 'SGA',
#  'SBC Communications': 'SBAC',
#  'SCYNEXIS Inc': 'SCYX',
#  'SEACOR Holdings': 'CKH',
#  'SG Blocks LLC': 'SGBX',
#  'SHC Inc': 'TYHT',
#  'SI International': 'SGMA',
#  'SI2 Technologies': 'SIFY',
#  'SIGA Technologies': 'SIFY',
#  'SITA Inc': 'SRVA',
#  'SJB Group': 'SJW',
#  'SK Telecom': 'SKM',
#  'SL Green Realty': 'SLG',
#  'SMART': 'SGH',
#  'SMART Technologies': 'SFS',
#  'SMS Holdings': 'SGH',
#  'SNF Inc': 'SNAP',
#  'SOLIX INC': 'SNGX',
#  'SOMS Technologies': 'SEDG',
#  'SRC Inc': 'SRCI',
#  'ST&P Communications': 'STRP',
#  'STMicroelectronics': 'STM',
#  'STN Inc': 'STN',
#  'STRONGER Inc': 'SRI',
#  'STS International': 'SXI',
#  'SVB Financial Group': 'SIVBO',
#  'SYKES Enterprises': 'SYKE',
#  'SYS Technologies': 'SNCR',
#  'T-Mobile Assn': 'TMUSP',
#  'T-Mobile USA': 'TMUSP',
#  'T2 Biosystems': 'TTOO',
#  'TCF Financial': 'TCF^D',
#  'TD Ameritrade': 'AMTD',
#  'TE Connectivity': 'TEL',
#  'TEAM Inc': 'GCI',
#  'TJX Companies': 'TJX',
#  'TOTAL SA': 'TOT',
#  'TTM Technologies': 'TTMI',
#  'TTi Technologies': 'TTMI',
#  'UBS AG': 'UBS',
#  'UMH Properties': 'UMH',
#  'UNICO': 'UNAM',
#  'US Corrections Corp': 'USG',
#  'US Ecology Corp': 'ECOL',
#  'US Ecology Idaho': 'ECOL',
#  'US Foods': 'USFD',
#  'US Inc': 'ECOL',
#  'US JVC Corp': 'USFD',
#  'US LEC Corp': 'USFD',
#  'USA Partners': 'USAC',
#  'VANTIV': 'VNTV',
#  'VIO Inc': 'VIA',
#  'VISX Inc': 'VVUS',
#  'WEC Energy Group': 'WEC',
#  'WECU Technologies': 'WSTL',
#  'WINGS Inc': 'WING',
#  'WPX Energy': 'WPXP',
#  'XOMA': 'XOMA',
#  'XPO Logistics': 'XPO',
#  'YRC Worldwide': 'YRCW',
#  'YUM! Brands': 'YUM'}

# %%
len(name2sharecode)
# Out:
# 304

# %%
co['result'] = [name2sharecode.get(co_row['coname'], 'nopublic') for _, co_row in co.iterrows()]
co['result'].head()

#write back
# Out:
# 0    nopublic
# 1    nopublic
# 2    nopublic
# 3    nopublic
# 4    nopublic
# Name: result, dtype: object

# %%
co['result'].describe()
# Out:
# count       222450
# unique         256
# top       nopublic
# freq        220249
# Name: result, dtype: object

# %%
co[co['result'] != 'nopublic']
# Out:
#                          coname      money  year comma   haha result
# 55            1-800-Flowers.com        ,0,  2009     ,  A8000   FLWS
# 56            1-800-Flowers.com    ,30000,  2010     ,  A8000   FLWS
# 195                      2U Inc    ,10000,  2015     ,  Y4000   TWOU
# 196                      2U Inc    ,20000,  2016     ,  Y4000   TWOU
# 247                  3D Systems    ,20000,  1998     ,  Y4000    DDD
# 412                     8X8 Inc    ,20000,  2006     ,  C4100   EGHT
# 413                     8X8 Inc        ,0,  2007     ,  C4100   EGHT
# 414                     8X8 Inc        ,0,  2008     ,  C4100   EGHT
# 462     A10 Networks Government    ,35000,  2014     ,  Y4000   ATEN
# 463     A10 Networks Government    ,35000,  2015     ,  Y4000   ATEN
# 488                    AAI Corp   ,420000,  1998     ,  D4000    AIR
# 494                    AAR Corp        ,0,  1998     ,  T1200    AIR
# 495                    AAR Corp    ,80000,  2001     ,  D2000    AIR
# 496                    AAR Corp   ,120000,  2002     ,  D2000    AIR
# 497                    AAR Corp   ,120000,  2003     ,  D2000    AIR
# 498                    AAR Corp   ,120000,  2004     ,  D2000    AIR
# 499                    AAR Corp   ,160000,  2005     ,  D2000    AIR
# 500                    AAR Corp   ,160000,  2006     ,  D2000    AIR
# 501                    AAR Corp   ,160000,  2007     ,  D2000    AIR
# 502                    AAR Corp   ,160000,  2008     ,  D2000    AIR
# 503                    AAR Corp   ,160000,  2009     ,  D2000    AIR
# 504                    AAR Corp   ,150000,  2010     ,  D2000    AIR
# 505                    AAR Corp   ,110000,  2011     ,  D2000    AIR
# 506                    AAR Corp   ,110000,  2012     ,  D2000    AIR
# 507                    AAR Corp   ,140000,  2013     ,  D2000    AIR
# 508                    AAR Corp    ,90000,  2014     ,  D2000    AIR
# 509                    AAR Corp   ,140000,  2015     ,  D2000    AIR
# 510                    AAR Corp    ,90000,  2016     ,  D2000    AIR
# 770                 ABIOMED Inc   ,160000,  2005     ,  H4100   ABMD
# 802              ABM Industries    ,50000,  2010     ,  f4500    ABM
# ...                         ...        ...   ...   ...    ...    ...
# 221050            XPO Logistics    ,60000,  2015     ,  Y4000    XPO
# 221051            XPO Logistics    ,30000,  2016     ,  Y4000    XPO
# 221720            YRC Worldwide   ,800000,  2009     ,  T3100   YRCW
# 221721            YRC Worldwide   ,645000,  2010     ,  T3100   YRCW
# 221722            YRC Worldwide   ,637500,  2011     ,  T3100   YRCW
# 221723            YRC Worldwide   ,500000,  2012     ,  T3100   YRCW
# 221724            YRC Worldwide   ,620000,  2013     ,  T3100   YRCW
# 221725            YRC Worldwide   ,320000,  2014     ,  T3100   YRCW
# 221726            YRC Worldwide   ,130000,  2015     ,  T3100   YRCW
# 221727            YRC Worldwide    ,90000,  2016     ,  T3100   YRCW
# 221781              YUM! Brands   ,490683,  1998     ,  G2900    YUM
# 221782              YUM! Brands   ,520000,  1999     ,  G2900    YUM
# 221783              YUM! Brands   ,550000,  2000     ,  G2900    YUM
# 221784              YUM! Brands   ,600000,  2001     ,  G2900    YUM
# 221785              YUM! Brands   ,660000,  2002     ,  G2900    YUM
# 221786              YUM! Brands   ,570000,  2003     ,  G2900    YUM
# 221787              YUM! Brands        ,0,  2003     ,  G2900    YUM
# 221788              YUM! Brands   ,690000,  2004     ,  G2900    YUM
# 221789              YUM! Brands   ,700000,  2005     ,  G2900    YUM
# 221790              YUM! Brands   ,903500,  2006     ,  G2900    YUM
# 221791              YUM! Brands   ,711795,  2007     ,  G2900    YUM
# 221792              YUM! Brands   ,870000,  2008     ,  G2900    YUM
# 221793              YUM! Brands  ,1430000,  2009     ,  G2900    YUM
# 221794              YUM! Brands  ,1400000,  2010     ,  G2900    YUM
# 221795              YUM! Brands  ,1140000,  2011     ,  G2900    YUM
# 221796              YUM! Brands   ,670000,  2012     ,  G2900    YUM
# 221797              YUM! Brands   ,690000,  2013     ,  G2900    YUM
# 221798              YUM! Brands   ,867000,  2014     ,  G2900    YUM
# 221799              YUM! Brands  ,1607985,  2015     ,  G2900    YUM
# 221800              YUM! Brands  ,1278203,  2016     ,  G2900    YUM
#
# [2201 rows x 6 columns]

# %%
co.to_csv("./jy_project.csv")
#write to csv
